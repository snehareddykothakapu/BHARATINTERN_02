# %% [markdown]
# **TASK 2**
#
# Make a system which tells whether the person will be
# save from sinking. What factors were
# most likely lead to success-socio-economic
# status, age, gender and more

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as mpl
from sklearn.linear_model import LogisticRegression
from tensorflow. keras.models import Sequential
from tensorflow. keras. layers import Dense
from sklearn.ensemble import RandomForestClassifier
from sklearn. tree import DecisionTreeClassifier
from xgboost import XGBRFClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
traindf = pd.read_csv("train_sneha.csv")

# %%
traindf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
testdf = pd.read_csv("test_sneha.csv")

# %%
testdf
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
traindf. isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
testdf.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
traindf.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
testdf. duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
impute_value = traindf["Age"].median()
traindf["Age"] = traindf["Age"].fillna(impute_value)
testdf["Age"] = testdf["Age"].fillna(impute_value)

# %%
traindf["IsFemale"] = (traindf['Sex'] == 'female').astype (int)
testdf["IsFemale"] = (testdf['Sex'] == 'female').astype(int)

# %%
predictors = ['Pclass','IsFemale','Age']
X_train = traindf[predictors].values
X_test = testdf[predictors].values
y_train = traindf['Survived']. values
X_train[:5]
# Out:
# array([[ 3.,  0., 22.],
#        [ 1.,  1., 38.],
#        [ 3.,  1., 26.],
#        [ 1.,  1., 35.],
#        [ 3.,  0., 35.]])

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model. fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_predict = model.predict(X_test)
y_predict[:10]
# Out:
# array([0, 0, 0, 0, 1, 0, 1, 0, 1, 0])

# %%
from sklearn.model_selection import cross_val_score
model = LogisticRegression (C=10)
scores = cross_val_score(model, X_train, y_train,cv=4)
scores
# Out:
# array([0.77578475, 0.79820628, 0.77578475, 0.78828829])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
from sklearn. svm import SVC, LinearSVC
model = SVC()
model. fit(X_train, y_train)
prediction_svm=model. predict(X_test)
print('The accuracy of the Support Vecton Machines Classifier is',round(accuracy_score(prediction_svm,y_predict)*100,2))
# Out:
# The accuracy of the Support Vecton Machines Classifier is 61.72
